# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, cloudiness, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tierra colorada
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | varkaus
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | nicoya
# Processing Record 8 of Set 1 | leningradskiy
# Processing Record 9 of Set 1 | morondava
# Processing Record 10 of Set 1 | angarsk
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | sitka
# Processing Record 13 of Set 1 | litovko
# Processing Record 14 of Set 1 | naze
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | kananga
# Processing Record 18 of Set 1 | hualmay
# Processing Record 19 of Set 1 | san vicente
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | bartica
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | zhanaozen
# Processing Record 27 of Set 1 | sokolo
# Processing Record 28 of Set 1 | riosucio
# Processing Record 29 of Set 1 | rayachoti
# Processing Record 30 of Set 1 | geraldton
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | guerrero negro
# Processing Record 35 of Set 1 | ye
# City not found. Skipping...
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | antalaha
# Processing Record 38 of Set 1 | aksarka
# Processing Record 39 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 40 of Set 1 | paranaiba
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | huangzhou
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | kampene
# Processing Record 47 of Set 1 | ryuo
# Processing Record 48 of Set 1 | lima
# Processing Record 49 of Set 1 | richards bay
# Processing Record 50 of Set 1 | damietta
# Processing Record 1 of Set 2 | pangnirtung
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | college
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | matagami
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | mogadishu
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | novobiryusinskiy
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | high level
# Processing Record 17 of Set 2 | sioux lookout
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | madinat sittah uktubar
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | kruisfontein
# Processing Record 23 of Set 2 | urgut
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | mount gambier
# Processing Record 27 of Set 2 | norman wells
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | saint-pierre
# Processing Record 30 of Set 2 | touros
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | kholtoson
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | faya
# Processing Record 36 of Set 2 | nemuro
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | gorontalo
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | barentu
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | nome
# Processing Record 44 of Set 2 | takhtamygda
# Processing Record 45 of Set 2 | yining
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | katsuura
# Processing Record 48 of Set 2 | sabha
# Processing Record 49 of Set 2 | zhezkazgan
# Processing Record 50 of Set 2 | albert lea
# Processing Record 1 of Set 3 | bat khela
# Processing Record 2 of Set 3 | kodinar
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | bainbridge
# Processing Record 5 of Set 3 | alofi
# Processing Record 6 of Set 3 | narsaq
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | kurchum
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | adrar
# Processing Record 11 of Set 3 | yulara
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | klaksvik
# Processing Record 14 of Set 3 | namibe
# Processing Record 15 of Set 3 | san pedro del pinatar
# Processing Record 16 of Set 3 | vila
# Processing Record 17 of Set 3 | bethanien
# Processing Record 18 of Set 3 | hidalgo
# Processing Record 19 of Set 3 | itarema
# Processing Record 20 of Set 3 | poya
# Processing Record 21 of Set 3 | seoul
# Processing Record 22 of Set 3 | srednekolymsk
# Processing Record 23 of Set 3 | sibolga
# Processing Record 24 of Set 3 | san ramon
# Processing Record 25 of Set 3 | yongan
# Processing Record 26 of Set 3 | shimoda
# Processing Record 27 of Set 3 | ardakan
# Processing Record 28 of Set 3 | port hedland
# Processing Record 29 of Set 3 | beysehir
# Processing Record 30 of Set 3 | carutapera
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | pevek
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | sambava
# Processing Record 37 of Set 3 | askiz
# Processing Record 38 of Set 3 | stephenville
# Processing Record 39 of Set 3 | pontian kecil
# Processing Record 40 of Set 3 | kletnya
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | asau
# Processing Record 44 of Set 3 | aklavik
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | provideniya
# Processing Record 47 of Set 3 | opuwo
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | teguise
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 4 | beloha
# Processing Record 3 of Set 4 | chutove
# Processing Record 4 of Set 4 | quixada
# Processing Record 5 of Set 4 | longyearbyen
# Processing Record 6 of Set 4 | dunedin
# Processing Record 7 of Set 4 | tabou
# Processing Record 8 of Set 4 | great yarmouth
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | bousse
# Processing Record 11 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | san patricio
# Processing Record 14 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 15 of Set 4 | lamu
# Processing Record 16 of Set 4 | georgetown
# Processing Record 17 of Set 4 | isangel
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | pingshan
# Processing Record 20 of Set 4 | murmansk
# Processing Record 21 of Set 4 | shadegan
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | salalah
# Processing Record 24 of Set 4 | vostok
# Processing Record 25 of Set 4 | grand-santi
# Processing Record 26 of Set 4 | byron bay
# Processing Record 27 of Set 4 | gori
# Processing Record 28 of Set 4 | kendari
# Processing Record 29 of Set 4 | vryburg
# Processing Record 30 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 4 | kathu
# Processing Record 32 of Set 4 | abha
# Processing Record 33 of Set 4 | tessalit
# Processing Record 34 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 4 | aykhal
# Processing Record 37 of Set 4 | albany
# Processing Record 38 of Set 4 | altamira
# Processing Record 39 of Set 4 | basco
# Processing Record 40 of Set 4 | zyryanka
# Processing Record 41 of Set 4 | baruun-urt
# Processing Record 42 of Set 4 | bubaque
# Processing Record 43 of Set 4 | hassleholm
# Processing Record 44 of Set 4 | karasjok
# Processing Record 45 of Set 4 | kirakira
# Processing Record 46 of Set 4 | russell
# Processing Record 47 of Set 4 | fomboni
# Processing Record 48 of Set 4 | batemans bay
# Processing Record 49 of Set 4 | hovd
# Processing Record 50 of Set 4 | vao
# Processing Record 1 of Set 5 | sinnamary
# Processing Record 2 of Set 5 | danville
# Processing Record 3 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 5 | burica
# City not found. Skipping...
# Processing Record 5 of Set 5 | verkhnyaya inta
# Processing Record 6 of Set 5 | kampot
# Processing Record 7 of Set 5 | natchez
# Processing Record 8 of Set 5 | letlhakane
# Processing Record 9 of Set 5 | los llanos de aridane
# Processing Record 10 of Set 5 | ampanihy
# Processing Record 11 of Set 5 | tullamore
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | peniche
# Processing Record 14 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 5 | paso de los toros
# Processing Record 16 of Set 5 | katha
# City not found. Skipping...
# Processing Record 17 of Set 5 | ucluelet
# Processing Record 18 of Set 5 | arraial do cabo
# Processing Record 19 of Set 5 | ancud
# Processing Record 20 of Set 5 | uyuni
# Processing Record 21 of Set 5 | lorengau
# Processing Record 22 of Set 5 | miramar
# Processing Record 23 of Set 5 | wamba
# Processing Record 24 of Set 5 | cap-chat
# Processing Record 25 of Set 5 | sederot
# Processing Record 26 of Set 5 | klobuck
# Processing Record 27 of Set 5 | loanda
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | pinhao
# Processing Record 30 of Set 5 | kodiak
# Processing Record 31 of Set 5 | reynoldsburg
# Processing Record 32 of Set 5 | tazovskiy
# Processing Record 33 of Set 5 | kahului
# Processing Record 34 of Set 5 | dullewala
# Processing Record 35 of Set 5 | berlevag
# Processing Record 36 of Set 5 | saint-georges
# Processing Record 37 of Set 5 | puri
# Processing Record 38 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 5 | te anau
# Processing Record 40 of Set 5 | kavaratti
# Processing Record 41 of Set 5 | tasiilaq
# Processing Record 42 of Set 5 | fukue
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | thanh hoa
# Processing Record 45 of Set 5 | samarai
# Processing Record 46 of Set 5 | arco
# Processing Record 47 of Set 5 | san juan
# Processing Record 48 of Set 5 | riyadh
# Processing Record 49 of Set 5 | san luis
# Processing Record 50 of Set 5 | progreso
# Processing Record 1 of Set 6 | kangaatsiaq
# Processing Record 2 of Set 6 | gold coast
# Processing Record 3 of Set 6 | severnyy
# Processing Record 4 of Set 6 | newport
# Processing Record 5 of Set 6 | taltal
# Processing Record 6 of Set 6 | umm lajj
# Processing Record 7 of Set 6 | rio gallegos
# Processing Record 8 of Set 6 | swan hill
# Processing Record 9 of Set 6 | clyde river
# Processing Record 10 of Set 6 | arlit
# Processing Record 11 of Set 6 | ropczyce
# Processing Record 12 of Set 6 | faanui
# Processing Record 13 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 6 | valparaiso
# Processing Record 15 of Set 6 | ithaca
# Processing Record 16 of Set 6 | ahipara
# Processing Record 17 of Set 6 | topeka
# Processing Record 18 of Set 6 | lasa
# Processing Record 19 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 6 | lesnoy
# Processing Record 21 of Set 6 | roma
# Processing Record 22 of Set 6 | new norfolk
# Processing Record 23 of Set 6 | palmas bellas
# Processing Record 24 of Set 6 | krasnoselkup
# Processing Record 25 of Set 6 | tuktoyaktuk
# Processing Record 26 of Set 6 | bilma
# Processing Record 27 of Set 6 | auki
# Processing Record 28 of Set 6 | poronaysk
# Processing Record 29 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 30 of Set 6 | pareora
# Processing Record 31 of Set 6 | waddan
# Processing Record 32 of Set 6 | gat
# Processing Record 33 of Set 6 | bilibino
# Processing Record 34 of Set 6 | ribeira grande
# Processing Record 35 of Set 6 | shieli
# Processing Record 36 of Set 6 | hendaye
# Processing Record 37 of Set 6 | kazachinskoye
# Processing Record 38 of Set 6 | stykkisholmur
# Processing Record 39 of Set 6 | rosetown
# Processing Record 40 of Set 6 | east london
# Processing Record 41 of Set 6 | komatipoort
# Processing Record 42 of Set 6 | gizo
# Processing Record 43 of Set 6 | chumikan
# Processing Record 44 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 6 | miri
# Processing Record 46 of Set 6 | saint anthony
# Processing Record 47 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 48 of Set 6 | zlutice
# Processing Record 49 of Set 6 | hobyo
# Processing Record 50 of Set 6 | katobu
# Processing Record 1 of Set 7 | constitucion
# Processing Record 2 of Set 7 | eureka
# Processing Record 3 of Set 7 | aracati
# Processing Record 4 of Set 7 | kismayo
# Processing Record 5 of Set 7 | mana
# Processing Record 6 of Set 7 | bandarbeyla
# Processing Record 7 of Set 7 | maniitsoq
# Processing Record 8 of Set 7 | laguna
# Processing Record 9 of Set 7 | caravelas
# Processing Record 10 of Set 7 | moree
# Processing Record 11 of Set 7 | nizhniy kuranakh
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | salinas
# Processing Record 14 of Set 7 | waingapu
# Processing Record 15 of Set 7 | saint-augustin
# Processing Record 16 of Set 7 | vigrestad
# Processing Record 17 of Set 7 | cairns
# Processing Record 18 of Set 7 | portland
# Processing Record 19 of Set 7 | atambua
# Processing Record 20 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 7 | mount isa
# Processing Record 23 of Set 7 | fayaoue
# Processing Record 24 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 7 | bonavista
# Processing Record 26 of Set 7 | bardiyah
# Processing Record 27 of Set 7 | ashcroft
# Processing Record 28 of Set 7 | puerto baquerizo moreno
# Processing Record 29 of Set 7 | irpa irpa
# Processing Record 30 of Set 7 | dingle
# Processing Record 31 of Set 7 | port-gentil
# Processing Record 32 of Set 7 | mackay
# Processing Record 33 of Set 7 | regina
# Processing Record 34 of Set 7 | florianopolis
# Processing Record 35 of Set 7 | chernyshevskiy
# Processing Record 36 of Set 7 | nantucket
# Processing Record 37 of Set 7 | lompoc
# Processing Record 38 of Set 7 | fortuna
# Processing Record 39 of Set 7 | henties bay
# Processing Record 40 of Set 7 | coquimbo
# Processing Record 41 of Set 7 | urazovo
# Processing Record 42 of Set 7 | codrington
# Processing Record 43 of Set 7 | goldbach
# Processing Record 44 of Set 7 | tigil
# Processing Record 45 of Set 7 | la ronge
# Processing Record 46 of Set 7 | sainte-anne-des-monts
# Processing Record 47 of Set 7 | ugoofaaru
# Processing Record 48 of Set 7 | shumikha
# Processing Record 49 of Set 7 | joshimath
# Processing Record 50 of Set 7 | ostrovnoy
# Processing Record 1 of Set 8 | caetes
# Processing Record 2 of Set 8 | chicama
# Processing Record 3 of Set 8 | ballina
# Processing Record 4 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 8 | maba
# Processing Record 6 of Set 8 | atherton
# Processing Record 7 of Set 8 | tabo-o
# City not found. Skipping...
# Processing Record 8 of Set 8 | san cristobal
# Processing Record 9 of Set 8 | pisco
# Processing Record 10 of Set 8 | limuru
# Processing Record 11 of Set 8 | ibia
# Processing Record 12 of Set 8 | port keats
# Processing Record 13 of Set 8 | santa cruz
# Processing Record 14 of Set 8 | buraydah
# Processing Record 15 of Set 8 | necochea
# Processing Record 16 of Set 8 | cabra
# Processing Record 17 of Set 8 | malchin
# Processing Record 18 of Set 8 | dutse
# Processing Record 19 of Set 8 | tirumullaivasal
# Processing Record 20 of Set 8 | itaituba
# Processing Record 21 of Set 8 | westport
# Processing Record 22 of Set 8 | nouakchott
# Processing Record 23 of Set 8 | jerome
# Processing Record 24 of Set 8 | loikaw
# Processing Record 25 of Set 8 | alice springs
# Processing Record 26 of Set 8 | valdemarpils
# Processing Record 27 of Set 8 | zwiesel
# Processing Record 28 of Set 8 | zhigansk
# Processing Record 29 of Set 8 | smithers
# Processing Record 30 of Set 8 | searcy
# Processing Record 31 of Set 8 | ewa beach
# Processing Record 32 of Set 8 | terre haute
# Processing Record 33 of Set 8 | choya
# Processing Record 34 of Set 8 | mecca
# Processing Record 35 of Set 8 | saint-louis
# Processing Record 36 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 8 | dover
# Processing Record 38 of Set 8 | port hardy
# Processing Record 39 of Set 8 | tuatapere
# Processing Record 40 of Set 8 | manuel doblado
# City not found. Skipping...
# Processing Record 41 of Set 8 | kudahuvadhoo
# Processing Record 42 of Set 8 | qeshm
# Processing Record 43 of Set 8 | hay river
# Processing Record 44 of Set 8 | adwa
# Processing Record 45 of Set 8 | lago da pedra
# Processing Record 46 of Set 8 | margate
# Processing Record 47 of Set 8 | bakchar
# Processing Record 48 of Set 8 | rantepao
# Processing Record 49 of Set 8 | portoferraio
# Processing Record 50 of Set 8 | chernyy yar
# Processing Record 1 of Set 9 | guantanamo
# Processing Record 2 of Set 9 | maxixe
# Processing Record 3 of Set 9 | bazarnyy syzgan
# Processing Record 4 of Set 9 | karpathos
# Processing Record 5 of Set 9 | lumeje
# Processing Record 6 of Set 9 | biak
# Processing Record 7 of Set 9 | tacuarembo
# Processing Record 8 of Set 9 | vila do maio
# Processing Record 9 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 9 | savannah bight
# Processing Record 11 of Set 9 | mandalgovi
# Processing Record 12 of Set 9 | moussoro
# Processing Record 13 of Set 9 | vila velha
# Processing Record 14 of Set 9 | bonfim
# Processing Record 15 of Set 9 | karatuzskoye
# Processing Record 16 of Set 9 | puerto colombia
# Processing Record 17 of Set 9 | guasdualito
# Processing Record 18 of Set 9 | nadvoitsy
# Processing Record 19 of Set 9 | mayo
# Processing Record 20 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 9 | whitehorse
# Processing Record 22 of Set 9 | salmas
# Processing Record 23 of Set 9 | san lorenzo
# Processing Record 24 of Set 9 | khani
# Processing Record 25 of Set 9 | knysna
# Processing Record 26 of Set 9 | saskylakh
# Processing Record 27 of Set 9 | saginaw
# Processing Record 28 of Set 9 | oktyabrskiy
# Processing Record 29 of Set 9 | chuy
# Processing Record 30 of Set 9 | alegrete
# Processing Record 31 of Set 9 | paredon
# Processing Record 32 of Set 9 | ust-ishim
# Processing Record 33 of Set 9 | agaro
# Processing Record 34 of Set 9 | broken hill
# Processing Record 35 of Set 9 | acari
# Processing Record 36 of Set 9 | gawan
# Processing Record 37 of Set 9 | boatlaname
# City not found. Skipping...
# Processing Record 38 of Set 9 | north bend
# Processing Record 39 of Set 9 | broome
# Processing Record 40 of Set 9 | darhan
# Processing Record 41 of Set 9 | santo estevao
# Processing Record 42 of Set 9 | rundu
# Processing Record 43 of Set 9 | esperance
# Processing Record 44 of Set 9 | teguldet
# Processing Record 45 of Set 9 | pronsk
# Processing Record 46 of Set 9 | deputatskiy
# Processing Record 47 of Set 9 | basoko
# Processing Record 48 of Set 9 | kaseda
# Processing Record 49 of Set 9 | sola
# Processing Record 50 of Set 9 | elizabeth city
# Processing Record 1 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 10 | tateyama
# Processing Record 3 of Set 10 | angelholm
# City not found. Skipping...
# Processing Record 4 of Set 10 | tual
# Processing Record 5 of Set 10 | hamilton
# Processing Record 6 of Set 10 | rincon
# Processing Record 7 of Set 10 | cayenne
# Processing Record 8 of Set 10 | teya
# Processing Record 9 of Set 10 | port augusta
# Processing Record 10 of Set 10 | senador jose porfirio
# Processing Record 11 of Set 10 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 12 of Set 10 | mayumba
# Processing Record 13 of Set 10 | zhengjiatun
# Processing Record 14 of Set 10 | do gonbadan
# Processing Record 15 of Set 10 | ajdabiya
# Processing Record 16 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 10 | yumen
# Processing Record 18 of Set 10 | dezful
# Processing Record 19 of Set 10 | hami
# Processing Record 20 of Set 10 | yemelyanovo
# Processing Record 21 of Set 10 | novo aripuana
# Processing Record 22 of Set 10 | lavrentiya
# Processing Record 23 of Set 10 | blackpool
# Processing Record 24 of Set 10 | bima
# Processing Record 25 of Set 10 | takoradi
# Processing Record 26 of Set 10 | leshukonskoye
# Processing Record 27 of Set 10 | mus
# Processing Record 28 of Set 10 | coro
# Processing Record 29 of Set 10 | gamba
# Processing Record 30 of Set 10 | chenghai
# Processing Record 31 of Set 10 | taoudenni
# Processing Record 32 of Set 10 | olinda
# Processing Record 33 of Set 10 | oranjemund
# Processing Record 34 of Set 10 | pouso alegre
# Processing Record 35 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 10 | chardara
# Processing Record 37 of Set 10 | yaring
# Processing Record 38 of Set 10 | lamlash
# Processing Record 39 of Set 10 | victor harbor
# Processing Record 40 of Set 10 | saint-prosper
# Processing Record 41 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 10 | marawi
# Processing Record 43 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 10 | breves
# Processing Record 45 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 46 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 47 of Set 10 | evensk
# Processing Record 48 of Set 10 | honiara
# Processing Record 49 of Set 10 | sinop
# Processing Record 50 of Set 10 | dalinghe
# City not found. Skipping...
# Processing Record 1 of Set 11 | port blair
# Processing Record 2 of Set 11 | balatonkenese
# Processing Record 3 of Set 11 | san quintin
# Processing Record 4 of Set 11 | fulacunda
# City not found. Skipping...
# Processing Record 5 of Set 11 | bathsheba
# Processing Record 6 of Set 11 | sawakin
# Processing Record 7 of Set 11 | malangali
# Processing Record 8 of Set 11 | abu samrah
# Processing Record 9 of Set 11 | the valley
# Processing Record 10 of Set 11 | kampong chhnang
# Processing Record 11 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 11 | kushiro
# Processing Record 13 of Set 11 | vanimo
# Processing Record 14 of Set 11 | valleyview
# Processing Record 15 of Set 11 | comodoro rivadavia
# Processing Record 16 of Set 11 | aybak
# City not found. Skipping...
# Processing Record 17 of Set 11 | palmer
# Processing Record 18 of Set 11 | navalcarnero
# Processing Record 19 of Set 11 | alyangula
# Processing Record 20 of Set 11 | grand gaube
# Processing Record 21 of Set 11 | tautira
# Processing Record 22 of Set 11 | grindavik
# Processing Record 23 of Set 11 | prado
# Processing Record 24 of Set 11 | junagarh
# Processing Record 25 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 11 | kalmunai
# Processing Record 27 of Set 11 | kautokeino
# Processing Record 28 of Set 11 | fort nelson
# Processing Record 29 of Set 11 | namatanai
# Processing Record 30 of Set 11 | missungwi
# Processing Record 31 of Set 11 | hammerfest
# Processing Record 32 of Set 11 | svetlogorsk
# Processing Record 33 of Set 11 | moose factory
# Processing Record 34 of Set 11 | hofn
# Processing Record 35 of Set 11 | xiangdong
# City not found. Skipping...
# Processing Record 36 of Set 11 | slave lake
# Processing Record 37 of Set 11 | kaitangata
# Processing Record 38 of Set 11 | abbeville
# Processing Record 39 of Set 11 | blagoveshchenka
# Processing Record 40 of Set 11 | ingham
# Processing Record 41 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 11 | fereydun kenar
# Processing Record 43 of Set 11 | ust-uda
# Processing Record 44 of Set 11 | trat
# Processing Record 45 of Set 11 | corning
# Processing Record 46 of Set 11 | polunochnoye
# Processing Record 47 of Set 11 | santa cruz del sur
# Processing Record 48 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 11 | pokhara
# Processing Record 50 of Set 11 | inuvik
# Processing Record 1 of Set 12 | vezirkopru
# Processing Record 2 of Set 12 | najran
# Processing Record 3 of Set 12 | shingu
# Processing Record 4 of Set 12 | eyl
# Processing Record 5 of Set 12 | oistins
# Processing Record 6 of Set 12 | xining
# Processing Record 7 of Set 12 | dothan
# Processing Record 8 of Set 12 | niono
# Processing Record 9 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 12 | mackenzie
# Processing Record 11 of Set 12 | lydenburg
# Processing Record 12 of Set 12 | dorado
# Processing Record 13 of Set 12 | feicheng
# Processing Record 14 of Set 12 | meadow lake
# Processing Record 15 of Set 12 | kropotkin
# Processing Record 16 of Set 12 | shiraz
# Processing Record 17 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 12 | serenje
# Processing Record 19 of Set 12 | banda aceh
# Processing Record 20 of Set 12 | kedzierzyn-kozle
# Processing Record 21 of Set 12 | praia da vitoria
# Processing Record 22 of Set 12 | kinsale
# Processing Record 23 of Set 12 | vaitape
# Processing Record 24 of Set 12 | talnakh
# Processing Record 25 of Set 12 | aripuana
# Processing Record 26 of Set 12 | jijiga
# Processing Record 27 of Set 12 | mogok
# Processing Record 28 of Set 12 | balykshi
# Processing Record 29 of Set 12 | zunyi
# Processing Record 30 of Set 12 | kuala krai
# City not found. Skipping...
# Processing Record 31 of Set 12 | ilulissat
# Processing Record 32 of Set 12 | denpasar
# Processing Record 33 of Set 12 | port-cartier
# Processing Record 34 of Set 12 | dhidhdhoo
# Processing Record 35 of Set 12 | nhulunbuy
# Processing Record 36 of Set 12 | butler
# Processing Record 37 of Set 12 | verkhoyansk
# Processing Record 38 of Set 12 | paamiut
# Processing Record 39 of Set 12 | igarka
# Processing Record 40 of Set 12 | laguna de perlas
# Processing Record 41 of Set 12 | jiuquan
# Processing Record 42 of Set 12 | wiarton
# Processing Record 43 of Set 12 | baripada
# Processing Record 44 of Set 12 | levelland
# Processing Record 45 of Set 12 | dillon
# Processing Record 46 of Set 12 | haines junction
# Processing Record 47 of Set 12 | beaverlodge
# Processing Record 48 of Set 12 | monte azul
# Processing Record 49 of Set 12 | santa maria
# Processing Record 50 of Set 12 | jinka
# Processing Record 1 of Set 13 | beringovskiy
# Processing Record 2 of Set 13 | arroyo
# Processing Record 3 of Set 13 | camana
# Processing Record 4 of Set 13 | vardo
# Processing Record 5 of Set 13 | xuddur
# Processing Record 6 of Set 13 | qingdao
# Processing Record 7 of Set 13 | georgiyevka
# Processing Record 8 of Set 13 | sechura
# Processing Record 9 of Set 13 | okha
# Processing Record 10 of Set 13 | borogontsy
# Processing Record 11 of Set 13 | rocha
# Processing Record 12 of Set 13 | el penol
# Processing Record 13 of Set 13 | jakar
# Processing Record 14 of Set 13 | kloulklubed
# Processing Record 15 of Set 13 | bay city
# Processing Record 16 of Set 13 | qurayyat
# Processing Record 17 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 13 | paragominas
# Processing Record 19 of Set 13 | zaoyang
# Processing Record 20 of Set 13 | ravar
# Processing Record 21 of Set 13 | vertientes
# Processing Record 22 of Set 13 | fairbanks
# Processing Record 23 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 13 | souillac
# Processing Record 25 of Set 13 | japura
# Processing Record 26 of Set 13 | kidal
# Processing Record 27 of Set 13 | vihti
# Processing Record 28 of Set 13 | amli
# Processing Record 29 of Set 13 | dalbandin
# Processing Record 30 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 13 | nieuw amsterdam
# Processing Record 32 of Set 13 | tamandare
# Processing Record 33 of Set 13 | gazanjyk
# Processing Record 34 of Set 13 | san policarpo
# Processing Record 35 of Set 13 | kungurtug
# Processing Record 36 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 13 | yoichi
# Processing Record 38 of Set 13 | umba
# Processing Record 39 of Set 13 | vila franca do campo
# Processing Record 40 of Set 13 | san rafael
# Processing Record 41 of Set 13 | chapais
# Processing Record 42 of Set 13 | chopda
# Processing Record 43 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 13 | nyuksenitsa
# Processing Record 45 of Set 13 | nioro
# Processing Record 46 of Set 13 | goderich
# Processing Record 47 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 13 | ryotsu
# Processing Record 49 of Set 13 | birao
# Processing Record 50 of Set 13 | brae
# Processing Record 1 of Set 14 | rawson
# Processing Record 2 of Set 14 | lazaro cardenas
# Processing Record 3 of Set 14 | hakkari
# Processing Record 4 of Set 14 | bailieborough
# Processing Record 5 of Set 14 | aktas
# Processing Record 6 of Set 14 | odweyne
# Processing Record 7 of Set 14 | burnie
# Processing Record 8 of Set 14 | bushehr
# Processing Record 9 of Set 14 | porto murtinho
# Processing Record 10 of Set 14 | tromso
# Processing Record 11 of Set 14 | avera
# Processing Record 12 of Set 14 | homer
# Processing Record 13 of Set 14 | krasnyy chikoy
# Processing Record 14 of Set 14 | lerwick
# Processing Record 15 of Set 14 | nuevitas
# Processing Record 16 of Set 14 | korla
# Processing Record 17 of Set 14 | florida
# Processing Record 18 of Set 14 | shimanovsk
# Processing Record 19 of Set 14 | yingzhong
# City not found. Skipping...
# Processing Record 20 of Set 14 | iralaya
# Processing Record 21 of Set 14 | rawlins
# Processing Record 22 of Set 14 | buala
# Processing Record 23 of Set 14 | salamiyah
# Processing Record 24 of Set 14 | mineral wells
# Processing Record 25 of Set 14 | wyndham
# Processing Record 26 of Set 14 | moncton
# Processing Record 27 of Set 14 | ouargaye
# Processing Record 28 of Set 14 | ranghulu
# Processing Record 29 of Set 14 | poum
# Processing Record 30 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 14 | uyskoye
# Processing Record 32 of Set 14 | mossendjo
# Processing Record 33 of Set 14 | gazni
# City not found. Skipping...
# Processing Record 34 of Set 14 | galle
# Processing Record 35 of Set 14 | mareeba
# Processing Record 36 of Set 14 | la macarena
# Processing Record 37 of Set 14 | tsaratanana
# Processing Record 38 of Set 14 | neiafu
# Processing Record 39 of Set 14 | manokwari
# Processing Record 40 of Set 14 | nueve de julio
# Processing Record 41 of Set 14 | maraba
# Processing Record 42 of Set 14 | yeppoon
# Processing Record 43 of Set 14 | komsomolskiy
# Processing Record 44 of Set 14 | tiksi
# Processing Record 45 of Set 14 | belle fourche
# Processing Record 46 of Set 14 | correntina
# Processing Record 47 of Set 14 | myre
# Processing Record 48 of Set 14 | merritt island
# Processing Record 49 of Set 14 | chenzhou
# Processing Record 50 of Set 14 | nuuk
# Processing Record 1 of Set 15 | sibu
# Processing Record 2 of Set 15 | guozhen
# Processing Record 3 of Set 15 | san pedro
# Processing Record 4 of Set 15 | otukpo
# Processing Record 5 of Set 15 | silver city
# Processing Record 6 of Set 15 | iida
# Processing Record 7 of Set 15 | manono
# Processing Record 8 of Set 15 | lahaina
# Processing Record 9 of Set 15 | jizan
# Processing Record 10 of Set 15 | qarqin
# Processing Record 11 of Set 15 | sao francisco de assis
# Processing Record 12 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 13 of Set 15 | buchanan
# Processing Record 14 of Set 15 | shar
# Processing Record 15 of Set 15 | atasu
# Processing Record 16 of Set 15 | youkounkoun
# Processing Record 17 of Set 15 | tlacotepec
# Processing Record 18 of Set 15 | roanoke
# Processing Record 19 of Set 15 | ponta delgada
# Processing Record 20 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 21 of Set 15 | xianyang
# Processing Record 22 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 15 | kayerkan
# Processing Record 24 of Set 15 | andira
# Processing Record 25 of Set 15 | chifeng
# Processing Record 26 of Set 15 | ban chang
# Processing Record 27 of Set 15 | kabalo
# Processing Record 28 of Set 15 | labuhan
# Processing Record 29 of Set 15 | karasuk
# Processing Record 30 of Set 15 | suluq
# Processing Record 31 of Set 15 | tapes
# Processing Record 32 of Set 15 | hojai
# Processing Record 33 of Set 15 | laje
# Processing Record 34 of Set 15 | gympie
# Processing Record 35 of Set 15 | hailar
# Processing Record 36 of Set 15 | mudgee
# Processing Record 37 of Set 15 | khartoum
# Processing Record 38 of Set 15 | batagay
# Processing Record 39 of Set 15 | alberton
# Processing Record 40 of Set 15 | bismarck
# Processing Record 41 of Set 15 | torrington
# Processing Record 42 of Set 15 | derzhavinsk
# Processing Record 43 of Set 15 | tura
# Processing Record 44 of Set 15 | dwarka
# Processing Record 45 of Set 15 | moron
# Processing Record 46 of Set 15 | san borja
# Processing Record 47 of Set 15 | eenhana
# Processing Record 48 of Set 15 | lieksa
# Processing Record 49 of Set 15 | sanming
# Processing Record 50 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 16 | liancheng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0  Tierra Colorada  17.1667  -99.5833     91.63       broken clouds        48
# 1          Iqaluit  63.7506  -68.5145     31.73          light snow       100
# 2        Carnarvon -24.8667  113.6333     55.47       broken clouds        82
# 3        Upernavik  72.7868  -56.1549     31.39    scattered clouds        88
# 4          Varkaus  62.3153   27.8730     52.30     overcast clouds        67
# 5          Ushuaia -54.8000  -68.3000     29.86       broken clouds       100
# 6           Nicoya  10.1483  -85.4520     90.95     overcast clouds        53
# 7    Leningradskiy  69.3833  178.4167     30.74       broken clouds        83
# 8        Morondava -20.2833   44.2833     69.76     overcast clouds        85
# 9          Angarsk  52.5367  103.8864     39.92       broken clouds        95
#
#    Cloudiness  Wind Speed Country
# 0          83        6.71      MX
# 1          90        8.01      CA
# 2          81       12.66      AU
# 3          30        6.98      GL
# 4          98        3.58      FI
# 5          75       11.50      AR
# 6          91        6.35      CR
# 7          53       14.83      RU
# 8         100        6.82      MG
# 9          77        4.32      RU

# %%
# Reorder the columns
city_data_new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[city_data_new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tierra Colorada      MX  17.1667  -99.5833     91.63        48          83
# 1          Iqaluit      CA  63.7506  -68.5145     31.73       100          90
# 2        Carnarvon      AU -24.8667  113.6333     55.47        82          81
# 3        Upernavik      GL  72.7868  -56.1549     31.39        88          30
# 4          Varkaus      FI  62.3153   27.8730     52.30        67          98
# 5          Ushuaia      AR -54.8000  -68.3000     29.86       100          75
# 6           Nicoya      CR  10.1483  -85.4520     90.95        53          91
# 7    Leningradskiy      RU  69.3833  178.4167     30.74        83          53
# 8        Morondava      MG -20.2833   44.2833     69.76        85         100
# 9          Angarsk      RU  52.5367  103.8864     39.92        95          77
#
#    Wind Speed Current Description
# 0        6.71       broken clouds
# 1        8.01          light snow
# 2       12.66       broken clouds
# 3        6.98    scattered clouds
# 4        3.58     overcast clouds
# 5       11.50       broken clouds
# 6        6.35     overcast clouds
# 7       14.83       broken clouds
# 8        6.82     overcast clouds
# 9        4.32       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
